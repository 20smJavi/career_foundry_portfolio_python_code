# %% [markdown]
# ## Importing Libraries and Data

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing Data
path = r'C:\Users\javir\Downloads\Javis Data Analytics stuff\Achievement 4\Instacart Basket Analysis'
ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'orders_products_merged_added.pkl'))

# %%
# Subsetting 1st million rows
df = ords_prods_merge[:1000000]

# %%
# Checking if subsetted correctly
df.shape
# Out:
# (1000000, 20)

# %%
df.head(10)
# Out:
#    order_id  user_id evaluation_set  order_number  orders_day_of_week  \
# 0   2539329        1          prior             1                   2
# 1   2539329        1          prior             1                   2
# 2   2539329        1          prior             1                   2
# 3   2539329        1          prior             1                   2
# 4   2539329        1          prior             1                   2
# 5   2398795        1          prior             2                   3
# 6   2398795        1          prior             2                   3
# 7   2398795        1          prior             2                   3
# 8   2398795        1          prior             2                   3
# 9   2398795        1          prior             2                   3
#
#    order_hour_of_day  days_since_prior_order  ordered_today  product_id  \
# 0                  8                     NaN           True       196.0
# ...

# %% [markdown]
# ### Working with grouping our data

# %%
# Grouping df by product_name
df.groupby('product_name')

# %%
# Grouping department_id's and displaying the average orders for each department
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              14.794925
# 2.0              17.085793
# 3.0              17.892742
# 4.0              17.880137
# 5.0              15.108513
# 6.0              15.352869
# 7.0              17.682741
# 8.0              16.496386
# 9.0              15.944846
# 10.0             20.104831
# 11.0             16.483104
# 12.0             15.614125
# 13.0             16.458631
# 14.0             17.523399
# 15.0             15.673392
# 16.0             18.012021
# 17.0             15.842139
# 18.0             19.349156
# 19.0             17.625805
# 20.0             17.113240
# 21.0             22.009038

# %%
# Alternative method
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     14.794925
# 2.0     17.085793
# 3.0     17.892742
# 4.0     17.880137
# 5.0     15.108513
# 6.0     15.352869
# 7.0     17.682741
# 8.0     16.496386
# 9.0     15.944846
# 10.0    20.104831
# 11.0    16.483104
# 12.0    15.614125
# 13.0    16.458631
# 14.0    17.523399
# 15.0    15.673392
# 16.0    18.012021
# 17.0    15.842139
# 18.0    19.349156
# 19.0    17.625805
# 20.0    17.113240
# 21.0    22.009038
# Name: order_number, dtype: float64

# %%
# Multiple arguements for aggreagating data
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1.0              14.794925   1  99
# 2.0              17.085793   1  98
# 3.0              17.892742   1  99
# 4.0              17.880137   1  99
# 5.0              15.108513   1  99
# 6.0              15.352869   1  99
# 7.0              17.682741   1  99
# 8.0              16.496386   1  91
# 9.0              15.944846   1  99
# 10.0             20.104831   1  99
# 11.0             16.483104   1  99
# 12.0             15.614125   1  99
# 13.0             16.458631   1  99
# 14.0             17.523399   1  99
# 15.0             15.673392   1  99
# 16.0             18.012021   1  99
# 17.0             15.842139   1  99
# 18.0             19.349156   1  99
# 19.0             17.625805   1  99
# 20.0             17.113240   1  99
# 21.0             22.009038   1  97

# %% [markdown]
# ### Creating a loyalty column, to identify our loyal customers

# %%
# Transforming our data to prepare our loyalty column
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Checking to see if our transform() successfully worked
ords_prods_merge.head(15)
# Out:
#     order_id  user_id evaluation_set  order_number  orders_day_of_week  \
# 0    2539329        1          prior             1                   2
# 1    2539329        1          prior             1                   2
# 2    2539329        1          prior             1                   2
# 3    2539329        1          prior             1                   2
# 4    2539329        1          prior             1                   2
# 5    2398795        1          prior             2                   3
# 6    2398795        1          prior             2                   3
# 7    2398795        1          prior             2                   3
# 8    2398795        1          prior             2                   3
# 9    2398795        1          prior             2                   3
# 10   2398795        1          prior             2                   3
# 11    473747        1          prior             3                   3
# ...

# %%
# Need aditional columns to check
ords_prods_merge.head(100)
# Out:
#     order_id  user_id evaluation_set  order_number  orders_day_of_week  \
# 0    2539329        1          prior             1                   2
# 1    2539329        1          prior             1                   2
# 2    2539329        1          prior             1                   2
# 3    2539329        1          prior             1                   2
# 4    2539329        1          prior             1                   2
# ..       ...      ...            ...           ...                 ...
# 95    738281        2          prior             4                   2
# 96    738281        2          prior             4                   2
# 97   1673511        2          prior             5                   3
# 98   1673511        2          prior             5                   3
# 99   1673511        2          prior             5                   3
#
#     order_hour_of_day  days_since_prior_order  ordered_today  product_id  \
# ...

# %%
# Changing table settings from Pandas to allow us to scroll through all rows requested
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id evaluation_set  order_number  orders_day_of_week  \
# 0    2539329        1          prior             1                   2
# 1    2539329        1          prior             1                   2
# 2    2539329        1          prior             1                   2
# 3    2539329        1          prior             1                   2
# 4    2539329        1          prior             1                   2
# 5    2398795        1          prior             2                   3
# 6    2398795        1          prior             2                   3
# 7    2398795        1          prior             2                   3
# 8    2398795        1          prior             2                   3
# 9    2398795        1          prior             2                   3
# 10   2398795        1          prior             2                   3
# 11    473747        1          prior             3                   3
# ...

# %% [markdown]
# ### Creating our loyalty label column

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    16381472
# Loyal customer      10679578
# New customer         5580218
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# ### Checking our data frame to see if everything worked correctly

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number', 'max_order']].head(500)
# Out:
#      user_id      loyalty_flag  order_number  max_order
# 0          1  Regular customer             1         11
# 1          1  Regular customer             1         11
# 2          1  Regular customer             1         11
# 3          1  Regular customer             1         11
# 4          1  Regular customer             1         11
# 5          1  Regular customer             2         11
# 6          1  Regular customer             2         11
# 7          1  Regular customer             2         11
# 8          1  Regular customer             2         11
# 9          1  Regular customer             2         11
# 10         1  Regular customer             2         11
# 11         1  Regular customer             3         11
# 12         1  Regular customer             3         11
# 13         1  Regular customer             3         11
# 14         1  Regular customer             3         11
# 15         1  Regular customer             3         11
# ...
