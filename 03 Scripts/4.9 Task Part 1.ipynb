# %% [markdown]
# ## Question  3 - Importing Libraries and Data

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing Data
path = r'C:\Users\javir\Downloads\Javis Data Analytics stuff\Achievement 4\Instacart Basket Analysis'
cust = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'))
ords_prods_merg = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merg_flag.pkl'))

# %% [markdown]
# ## Question 4 - Wrangle customer data

# %%
# Checking our columns and the values stored within those columns
cust.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %% [markdown]
# #### Renaming columns

# %%
# Changing these columns to fit a uniform look for our columns
cust.rename(columns = {'First Name' : 'first_name'}, inplace = True)
cust.rename(columns = {'Surnam' : 'last_name'}, inplace = True)
cust.rename(columns = {'Gender' : 'gender'}, inplace = True)
cust.rename(columns = {'STATE' : 'state'}, inplace = True)
cust.rename(columns = {'Age' : 'age'}, inplace = True)
# Changing these columns for clearer representation of what they stand for
cust.rename(columns = {'n_dependants' : 'num_of_dependants'}, inplace = True)
cust.rename(columns = {'fam_status' : 'family_status'}, inplace = True)

# %% [markdown]
# #### We aren't going to be dropping any columns as we don't know what kind of questions we are looking to answer. Keeping the data ensures we will have all tools available to answer questions if they arise.

# %% [markdown]
# ## Question 5 - Data quality check

# %% [markdown]
# #### Checklist:
# #### - Missing Values
# #### - Duplicate Values
# #### - Mixed-type data column

# %%
# Checking row counts
cust.shape
# Out:
# (206209, 10)

# %%
# Checking statistical info about our data set
cust.describe()
# Out:
#              user_id            age  num_of_dependants         income
# count  206209.000000  206209.000000      206209.000000  206209.000000
# mean   103105.000000      49.501646           1.499823   94632.852548
# std     59527.555167      18.480962           1.118433   42473.786988
# min         1.000000      18.000000           0.000000   25903.000000
# 25%     51553.000000      33.000000           0.000000   59874.000000
# 50%    103105.000000      49.000000           1.000000   93547.000000
# 75%    154657.000000      66.000000           3.000000  124244.000000
# max    206209.000000      81.000000           3.000000  593901.000000

# %%
# Checking dtyoes for columns
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   user_id            206209 non-null  int64
#  1   first_name         194950 non-null  object
#  2   last_name          206209 non-null  object
#  3   gender             206209 non-null  object
#  4   state              206209 non-null  object
#  5   age                206209 non-null  int64
#  6   date_joined        206209 non-null  object
#  7   num_of_dependants  206209 non-null  int64
#  8   family_status      206209 non-null  object
#  9   income             206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %% [markdown]
# #### - Missing Values

# %%
# Checking null values
cust.isnull().sum()
# Out:
# user_id                  0
# first_name           11259
# last_name                0
# gender                   0
# state                    0
# age                      0
# date_joined              0
# num_of_dependants        0
# family_status            0
# income                   0
# dtype: int64

# %%
# Located 11,259 rows of null values in first_name, creating a table inlcuding ONLY null values
cust_nan = cust[cust['first_name'].isnull() == True]

# %%
# I wont be removing these 11,259 rows, we still hold all the information about their account exluding their first name, the information can still be valuable
cust_nan.head()
# Out:
#      user_id first_name last_name  gender      state  age date_joined  \
# 53     76659        NaN   Gilbert    Male   Colorado   26    1/1/2017
# 73     13738        NaN     Frost  Female  Louisiana   39    1/1/2017
# 82     89996        NaN    Dawson  Female     Oregon   52    1/1/2017
# 99     96166        NaN   Oconnor    Male   Oklahoma   51    1/1/2017
# 105    29778        NaN    Dawson  Female       Utah   63    1/1/2017
#
#      num_of_dependants family_status  income
# 53                   2       married   41709
# 73                   0        single   82518
# 82                   3       married  117099
# 99                   1       married  155673
# 105                  3       married  151819

# %% [markdown]
# #### - Duplicate Values

# %%
# Checkign for duplicate rows within our dataframe
cust[cust.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, num_of_dependants, family_status, income]
# Index: []

# %% [markdown]
# #### - Mixed data-types

# %%
# Checking for mixed values
for col in cust.columns.tolist():
    weird = (cust[[col]].applymap(type) != cust[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (cust[weird]) > 0:
        print(col)
# Out:
# first_name

# %% [markdown]
# #### first_name column has mixed data, however as we saw earlier in .info() first_name is an dtype(object), indicating it is already set in string format

# %%
cust['first_name'] = cust['first_name'].astype('str')

# %%
# Confirmation of first_name being an object data type, executing code above did not alter dtype
cust['first_name'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Question 6 - Combine Customer Data with ords_prods_merge

# %%
pd.set_option("display.max_columns", None)
# Data set ords_prods_merge has already been imported
# Checking both data frames columns for potential keys
cust
# Out:
#         user_id first_name last_name  gender           state  age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
#         num_of_dependants family_status  income
# 0                       3       married  165665
# 1                       0        single   59285
# 2                       2       married   99568
# 3                       0        single   42049
# 4                       1       married   40374
# ...                   ...           ...     ...
# 206204                  1       married  148828
# 206205                  3       married  168639
# 206206                  2       married   53374
# 206207                  1       married   99799
# 206208                  1       married   57095
#
# [206209 rows x 10 columns]

# %%
ords_prods_merg
# Out:
#           order_id  user_id evaluation_set  order_number  orders_day_of_week  \
# 0          2539329        1          prior             1                   2
# 1          2539329        1          prior             1                   2
# 2          2539329        1          prior             1                   2
# 3          2539329        1          prior             1                   2
# 4          2539329        1          prior             1                   2
# ...            ...      ...            ...           ...                 ...
# 32641263   2977660   206209          prior            13                   1
# 32641264   2977660   206209          prior            13                   1
# 32641265   2977660   206209          prior            13                   1
# 32641266   2977660   206209          prior            13                   1
# 32641267    272231   206209          train            14                   6
#
#           order_hour_of_day  days_since_prior_order  ordered_today  \
# 0                         8                     NaN           True
# 1                         8                     NaN           True
# 2                         8                     NaN           True
# 3                         8                     NaN           True
# 4                         8                     NaN           True
# ...                     ...                     ...            ...
# 32641263                 12                     7.0          False
# 32641264                 12                     7.0          False
# 32641265                 12                     7.0          False
# 32641266                 12                     7.0          False
# 32641267                 14                    30.0          False
#
#           product_id  add_to_cart_order  reordered  \
# 0              196.0                1.0        0.0
# 1            14084.0                2.0        0.0
# 2            12427.0                3.0        0.0
# 3            26088.0                4.0        0.0
# 4            26405.0                5.0        0.0
# ...              ...                ...        ...
# 32641263     38730.0                6.0        0.0
# 32641264     31477.0                7.0        0.0
# 32641265      6567.0                8.0        0.0
# 32641266     22920.0                9.0        0.0
# 32641267         NaN                NaN        NaN
#
#                                      product_name  aisle_id  department_id  \
# 0                                            Soda      77.0            7.0
# 1         Organic Unsweetened Vanilla Almond Milk      91.0           16.0
# 2                             Original Beef Jerky      23.0           19.0
# 3                      Aged White Cheddar Popcorn      23.0           19.0
# 4                XL Pick-A-Size Paper Towel Rolls      54.0           17.0
# ...                                           ...       ...            ...
# 32641263          Brownie Crunch High Protein Bar       3.0           19.0
# 32641264    High Protein Bar Chunky Peanut Butter       3.0           19.0
# 32641265      Chocolate Peanut Butter Protein Bar       3.0           19.0
# 32641266      Roasted & Salted Shelled Pistachios     117.0           19.0
# 32641267                                      NaN       NaN            NaN
#
#           prices     _merge     busiest_day    busiest_days  \
# 0            9.0       both  Regularly busy  Regularly busy
# 1           12.5       both  Regularly busy  Regularly busy
# 2            4.4       both  Regularly busy  Regularly busy
# 3            4.7       both  Regularly busy  Regularly busy
# 4            1.0       both  Regularly busy  Regularly busy
# ...          ...        ...             ...             ...
# 32641263     5.9       both  Regularly busy  Regularly busy
# 32641264     4.2       both  Regularly busy  Regularly busy
# 32641265     4.9       both  Regularly busy  Regularly busy
# 32641266     1.7       both  Regularly busy  Regularly busy
# 32641267     NaN  left_only  Regularly busy  Regularly busy
#
#          busiest_days_revised busiest_period_of_day  max_order  \
# 0              Regularly busy         Fewest Orders         11
# 1              Regularly busy         Fewest Orders         11
# 2              Regularly busy         Fewest Orders         11
# 3              Regularly busy         Fewest Orders         11
# 4              Regularly busy         Fewest Orders         11
# ...                       ...                   ...        ...
# 32641263         Busiest days           Most Orders         14
# 32641264         Busiest days           Most Orders         14
# 32641265         Busiest days           Most Orders         14
# 32641266         Busiest days           Most Orders         14
# 32641267       Regularly busy           Most Orders         14
#
#               loyalty_flag  avg_spent spender_flag  order_frequency  \
# 0         Regular Customer   6.367797  Low spender             20.0
# 1         Regular Customer   6.367797  Low spender             20.0
# 2         Regular Customer   6.367797  Low spender             20.0
# 3         Regular Customer   6.367797  Low spender             20.0
# 4         Regular Customer   6.367797  Low spender             20.0
# ...                    ...        ...          ...              ...
# 32641263  Regular Customer   7.058915  Low spender             22.0
# 32641264  Regular Customer   7.058915  Low spender             22.0
# 32641265  Regular Customer   7.058915  Low spender             22.0
# 32641266  Regular Customer   7.058915  Low spender             22.0
# 32641267  Regular Customer   7.058915  Low spender             22.0
#
#              frequency_flag
# 0         Frequent customer
# 1         Frequent customer
# 2         Frequent customer
# 3         Frequent customer
# 4         Frequent customer
# ...                     ...
# 32641263  Frequent customer
# 32641264  Frequent customer
# 32641265  Frequent customer
# 32641266  Frequent customer
# 32641267  Frequent customer
#
# [32641268 rows x 26 columns]

# %%
# Dropping '_merge' column, so we can check if we got a full match, and we cannot .merge() with indicator = True if '_merge' already exists
merg_final = ords_prods_merg.drop(columns = '_merge')

# %%
# Both data frames sharea common column 'user_id' which will be our key for the merge
combined = merg_final.merge(cust, on = 'user_id', how = 'left', indicator = True )

# %%
combined
# Out:
#           order_id  user_id evaluation_set  order_number  orders_day_of_week  \
# 0          2539329        1          prior             1                   2
# 1          2539329        1          prior             1                   2
# 2          2539329        1          prior             1                   2
# 3          2539329        1          prior             1                   2
# 4          2539329        1          prior             1                   2
# ...            ...      ...            ...           ...                 ...
# 32641263   2977660   206209          prior            13                   1
# 32641264   2977660   206209          prior            13                   1
# 32641265   2977660   206209          prior            13                   1
# 32641266   2977660   206209          prior            13                   1
# 32641267    272231   206209          train            14                   6
#
#           order_hour_of_day  days_since_prior_order  ordered_today  \
# 0                         8                     NaN           True
# 1                         8                     NaN           True
# 2                         8                     NaN           True
# 3                         8                     NaN           True
# 4                         8                     NaN           True
# ...                     ...                     ...            ...
# 32641263                 12                     7.0          False
# 32641264                 12                     7.0          False
# 32641265                 12                     7.0          False
# 32641266                 12                     7.0          False
# 32641267                 14                    30.0          False
#
#           product_id  add_to_cart_order  reordered  \
# 0              196.0                1.0        0.0
# 1            14084.0                2.0        0.0
# 2            12427.0                3.0        0.0
# 3            26088.0                4.0        0.0
# 4            26405.0                5.0        0.0
# ...              ...                ...        ...
# 32641263     38730.0                6.0        0.0
# 32641264     31477.0                7.0        0.0
# 32641265      6567.0                8.0        0.0
# 32641266     22920.0                9.0        0.0
# 32641267         NaN                NaN        NaN
#
#                                      product_name  aisle_id  department_id  \
# 0                                            Soda      77.0            7.0
# 1         Organic Unsweetened Vanilla Almond Milk      91.0           16.0
# 2                             Original Beef Jerky      23.0           19.0
# 3                      Aged White Cheddar Popcorn      23.0           19.0
# 4                XL Pick-A-Size Paper Towel Rolls      54.0           17.0
# ...                                           ...       ...            ...
# 32641263          Brownie Crunch High Protein Bar       3.0           19.0
# 32641264    High Protein Bar Chunky Peanut Butter       3.0           19.0
# 32641265      Chocolate Peanut Butter Protein Bar       3.0           19.0
# 32641266      Roasted & Salted Shelled Pistachios     117.0           19.0
# 32641267                                      NaN       NaN            NaN
#
#           prices     busiest_day    busiest_days busiest_days_revised  \
# 0            9.0  Regularly busy  Regularly busy       Regularly busy
# 1           12.5  Regularly busy  Regularly busy       Regularly busy
# 2            4.4  Regularly busy  Regularly busy       Regularly busy
# 3            4.7  Regularly busy  Regularly busy       Regularly busy
# 4            1.0  Regularly busy  Regularly busy       Regularly busy
# ...          ...             ...             ...                  ...
# 32641263     5.9  Regularly busy  Regularly busy         Busiest days
# 32641264     4.2  Regularly busy  Regularly busy         Busiest days
# 32641265     4.9  Regularly busy  Regularly busy         Busiest days
# 32641266     1.7  Regularly busy  Regularly busy         Busiest days
# 32641267     NaN  Regularly busy  Regularly busy       Regularly busy
#
#          busiest_period_of_day  max_order      loyalty_flag  avg_spent  \
# 0                Fewest Orders         11  Regular Customer   6.367797
# 1                Fewest Orders         11  Regular Customer   6.367797
# 2                Fewest Orders         11  Regular Customer   6.367797
# 3                Fewest Orders         11  Regular Customer   6.367797
# 4                Fewest Orders         11  Regular Customer   6.367797
# ...                        ...        ...               ...        ...
# 32641263           Most Orders         14  Regular Customer   7.058915
# 32641264           Most Orders         14  Regular Customer   7.058915
# 32641265           Most Orders         14  Regular Customer   7.058915
# 32641266           Most Orders         14  Regular Customer   7.058915
# 32641267           Most Orders         14  Regular Customer   7.058915
#
#          spender_flag  order_frequency     frequency_flag first_name  \
# 0         Low spender             20.0  Frequent customer      Linda
# 1         Low spender             20.0  Frequent customer      Linda
# 2         Low spender             20.0  Frequent customer      Linda
# 3         Low spender             20.0  Frequent customer      Linda
# 4         Low spender             20.0  Frequent customer      Linda
# ...               ...              ...                ...        ...
# 32641263  Low spender             22.0  Frequent customer      Diana
# 32641264  Low spender             22.0  Frequent customer      Diana
# 32641265  Low spender             22.0  Frequent customer      Diana
# 32641266  Low spender             22.0  Frequent customer      Diana
# 32641267  Low spender             22.0  Frequent customer      Diana
#
#          last_name  gender    state  age date_joined  num_of_dependants  \
# 0           Nguyen  Female  Alabama   31   2/17/2019                  3
# 1           Nguyen  Female  Alabama   31   2/17/2019                  3
# 2           Nguyen  Female  Alabama   31   2/17/2019                  3
# 3           Nguyen  Female  Alabama   31   2/17/2019                  3
# 4           Nguyen  Female  Alabama   31   2/17/2019                  3
# ...            ...     ...      ...  ...         ...                ...
# 32641263   Donovan  Female     Iowa   74   9/14/2019                  3
# 32641264   Donovan  Female     Iowa   74   9/14/2019                  3
# 32641265   Donovan  Female     Iowa   74   9/14/2019                  3
# 32641266   Donovan  Female     Iowa   74   9/14/2019                  3
# 32641267   Donovan  Female     Iowa   74   9/14/2019                  3
#
#          family_status  income _merge
# 0              married   40423   both
# 1              married   40423   both
# 2              married   40423   both
# 3              married   40423   both
# 4              married   40423   both
# ...                ...     ...    ...
# 32641263       married  137969   both
# 32641264       married  137969   both
# 32641265       married  137969   both
# 32641266       married  137969   both
# 32641267       married  137969   both
#
# [32641268 rows x 35 columns]

# %%
combined['_merge'].value_counts()
# Out:
# both          32641268
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# ## Question 8 - Export

# %%
combined.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'cust_combined.pkl'))
